# %% [markdown]
# <a href="https://colab.research.google.com/github/swadeshyewale100/deep-learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# Step 1 Read the dataset

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/main/PowerPlant.csv"
df = pd.read_csv(url)
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %% [markdown]
# ### step 2: basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
df.isna().sum()
# Out:
# AT    0
# V     0
# AP    0
# RH    0
# PE    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 41

# %%
df.duplicated().sum()/len(df)
# Out:
# 0.004285117056856187

# %%
df= df.drop_duplicates(keep='first')
df
# Out:
#          AT      V       AP     RH      PE
# 0      8.34  40.77  1010.84  90.01  480.48
# 1     23.64  58.49  1011.40  74.20  445.75
# 2     29.74  56.90  1007.15  41.91  438.76
# 3     19.07  49.69  1007.22  76.79  453.09
# 4     11.80  40.66  1017.13  97.20  464.43
# ...     ...    ...      ...    ...     ...
# 9563  15.12  48.92  1011.80  72.93  462.59
# 9564  33.41  77.95  1010.30  59.72  432.90
# 9565  15.99  43.34  1014.20  78.66  465.96
# 9566  17.65  59.87  1018.58  94.65  450.93
# 9567  23.68  51.30  1011.86  71.24  451.67
#
# [9527 rows x 5 columns]

# %%
X = df.drop(columns=['PE'])
Y = df[["PE"]]

# %%
X.head()
# Out:
#       AT      V       AP     RH
# 0   8.34  40.77  1010.84  90.01
# 1  23.64  58.49  1011.40  74.20
# 2  29.74  56.90  1007.15  41.91
# 3  19.07  49.69  1007.22  76.79
# 4  11.80  40.66  1017.13  97.20

# %%
Y.head()
# Out:
#        PE
# 0  480.48
# 1  445.75
# 2  438.76
# 3  453.09
# 4  464.43

# %% [markdown]
# ### step  preprocess X using pipeline

# %%
X.dtypes
# Out:
# AT    float64
# V     float64
# AP    float64
# RH    float64
# dtype: object

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = Pipeline(steps=[('impute', SimpleImputer(strategy='mean')),
                           ('scale', StandardScaler())]).set_output(transform='pandas')

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#          AT         V        AP        RH
# 0 -1.520448 -1.066041 -0.403535  1.141599
# 1  0.534897  0.330813 -0.309262  0.059223
# 2  1.354348  0.205475 -1.024725 -2.151400
# 3 -0.079020 -0.362884 -1.012941  0.236538
# 4 -1.055645 -1.074713  0.655349  1.633837

# %% [markdown]
# Apply Train Test split

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X_pre, Y, test_size=0.2, random_state=23)

# %%
xtrain.head()
# Out:
#             AT         V        AP        RH
# 7081 -1.873752 -1.023474 -1.682950  1.105314
# 2258 -0.655323 -1.034510  0.535825 -0.404947
# 659   0.636992  0.475071  0.549293 -0.162593
# 9441  0.408621  0.769104 -0.098832  1.119691
# 8478 -0.878321 -0.794869  1.066109  1.092307

# %%
ytrain.head()
# Out:
#           PE
# 7081  485.83
# 2258  469.69
# 659   447.73
# 9441  448.76
# 8478  469.09

# %%
ytest.head()
# Out:
#           PE
# 8316  427.65
# 9265  430.22
# 4287  445.80
# 5889  450.50
# 119   459.47

# %%
xtest.head()
# Out:
#             AT         V        AP        RH
# 8316  0.888201  1.394220 -1.265457  0.877338
# 9265  0.878798  1.606271  0.581278  0.756161
# 4287  0.643709  1.239715 -0.418686 -0.134524
# 5889 -0.179772  0.918091 -0.083681  0.919784
# 119   0.037853 -0.740477 -0.794093  0.092769

# %%
xtrain.shape
# Out:
# (7621, 4)

# %%
xtest.shape
# Out:
# (1906, 4)

# %%
xtrain.shape[1]
# Out:
# 4

# %% [markdown]
# Build the neral network

# %%
from keras.models import Sequential
from keras.layers import Dense, Input

# %%
# Intializze the model
model = Sequential()

# %%
# Add input layer
model.add(Input(shape=(xtrain.shape[1],)))

# %%
# Add Dense Hidden Layer 1
model.add(Dense(16, activation='relu'))

# %%
#Add Hidden layer 2
model.add(Dense(8, activation='relu'))

# %%
#Add output layer
model.add(Dense(1, activation='linear'))

# %%
# Compile the model
model.compile(loss="mse", metrics=["mae"], optimizer="adam")

# %%
hist =model.fit(xtrain, ytrain,
                validation_data=(xtest, ytest),
                epochs=60)
# Out:
# Epoch 1/60
# 239/239 [==============================] - 5s 7ms/step - loss: 201974.2031 - mae: 449.0507 - val_loss: 191438.1875 - val_mae: 437.1674
# Epoch 2/60
# 239/239 [==============================] - 1s 4ms/step - loss: 159537.9688 - mae: 397.4151 - val_loss: 118414.8359 - val_mae: 341.1956
# Epoch 3/60
# 239/239 [==============================] - 1s 4ms/step - loss: 73884.2578 - mae: 256.9842 - val_loss: 41237.2148 - val_mae: 179.9598
# Epoch 4/60
# 239/239 [==============================] - 1s 4ms/step - loss: 27797.9688 - mae: 143.1899 - val_loss: 22353.0801 - val_mae: 129.6695
# Epoch 5/60
# 239/239 [==============================] - 1s 4ms/step - loss: 18489.6348 - mae: 116.5557 - val_loss: 16180.5537 - val_mae: 110.3910
# Epoch 6/60
# 239/239 [==============================] - 1s 4ms/step - loss: 13156.9043 - mae: 97.9598 - val_loss: 10890.9443 - val_mae: 90.1546
# Epoch 7/60
# 239/239 [==============================] - 1s 4ms/step - loss: 8422.4570 - mae: 77.8093 - val_loss: 6475.8159 - val_mae: 68.6333
# Epoch 8/60
# 239/239 [==============================] - 1s 4ms/step - loss: 4750.2827 - mae: 57.4081 - val_loss: 3410.1445 - val_mae: 48.7821
# Epoch 9/60
# 239/239 [==============================] - 1s 4ms/step - loss: 2422.2478 - mae: 39.7271 - val_loss: 1666.3011 - val_mae: 32.4403
# Epoch 10/60
# 239/239 [==============================] - 1s 4ms/step - loss: 1188.1084 - mae: 26.4564 - val_loss: 821.8384 - val_mae: 21.7500
# Epoch 11/60
# 239/239 [==============================] - 1s 4ms/step - loss: 614.0963 - mae: 18.3254 - val_loss: 443.6052 - val_mae: 15.5814
# Epoch 12/60
# 239/239 [==============================] - 1s 4ms/step - loss: 353.7203 - mae: 13.7025 - val_loss: 271.2043 - val_mae: 12.2173
# Epoch 13/60
# 239/239 [==============================] - 1s 5ms/step - loss: 225.3355 - mae: 10.9519 - val_loss: 178.7834 - val_mae: 9.9015
# Epoch 14/60
# 239/239 [==============================] - 1s 5ms/step - loss: 154.2543 - mae: 9.0545 - val_loss: 127.0488 - val_mae: 8.4082
# Epoch 15/60
# 239/239 [==============================] - 1s 5ms/step - loss: 110.9060 - mae: 7.6895 - val_loss: 94.4751 - val_mae: 7.3167
# Epoch 16/60
# 239/239 [==============================] - 1s 3ms/step - loss: 83.4607 - mae: 6.6970 - val_loss: 72.4679 - val_mae: 6.3937
# Epoch 17/60
# 239/239 [==============================] - 1s 4ms/step - loss: 65.0352 - mae: 5.9339 - val_loss: 57.3042 - val_mae: 5.6865
# Epoch 18/60
# 239/239 [==============================] - 1s 4ms/step - loss: 53.1081 - mae: 5.3715 - val_loss: 48.4598 - val_mae: 5.2776
# Epoch 19/60
# 239/239 [==============================] - 1s 4ms/step - loss: 44.9392 - mae: 4.9684 - val_loss: 41.4698 - val_mae: 4.8454
# Epoch 20/60
# 239/239 [==============================] - 1s 4ms/step - loss: 39.1962 - mae: 4.6568 - val_loss: 36.7037 - val_mae: 4.5841
# Epoch 21/60
# 239/239 [==============================] - 1s 4ms/step - loss: 35.0524 - mae: 4.4308 - val_loss: 33.0659 - val_mae: 4.3462
# Epoch 22/60
# 239/239 [==============================] - 1s 4ms/step - loss: 31.8708 - mae: 4.2499 - val_loss: 30.3275 - val_mae: 4.1832
# Epoch 23/60
# 239/239 [==============================] - 1s 4ms/step - loss: 29.3142 - mae: 4.1048 - val_loss: 29.1494 - val_mae: 4.1003
# Epoch 24/60
# 239/239 [==============================] - 1s 3ms/step - loss: 27.4009 - mae: 3.9987 - val_loss: 26.9661 - val_mae: 3.9632
# Epoch 25/60
# 239/239 [==============================] - 1s 4ms/step - loss: 25.8015 - mae: 3.9092 - val_loss: 25.3001 - val_mae: 3.8515
# Epoch 26/60
# 239/239 [==============================] - 1s 4ms/step - loss: 24.5053 - mae: 3.8368 - val_loss: 24.3083 - val_mae: 3.7907
# Epoch 27/60
# 239/239 [==============================] - 1s 6ms/step - loss: 23.4411 - mae: 3.7751 - val_loss: 23.6525 - val_mae: 3.7761
# Epoch 28/60
# 239/239 [==============================] - 1s 6ms/step - loss: 22.7179 - mae: 3.7309 - val_loss: 23.0028 - val_mae: 3.7211
# Epoch 29/60
# 239/239 [==============================] - 1s 4ms/step - loss: 22.1816 - mae: 3.6951 - val_loss: 22.5569 - val_mae: 3.6894
# Epoch 30/60
# 239/239 [==============================] - 1s 4ms/step - loss: 21.6420 - mae: 3.6652 - val_loss: 22.0528 - val_mae: 3.6381
# Epoch 31/60
# 239/239 [==============================] - 1s 4ms/step - loss: 21.3347 - mae: 3.6528 - val_loss: 22.1929 - val_mae: 3.6229
# Epoch 32/60
# 239/239 [==============================] - 1s 4ms/step - loss: 21.0494 - mae: 3.6315 - val_loss: 21.6510 - val_mae: 3.6002
# Epoch 33/60
# 239/239 [==============================] - 1s 4ms/step - loss: 20.8844 - mae: 3.6263 - val_loss: 21.4940 - val_mae: 3.5802
# Epoch 34/60
# 239/239 [==============================] - 1s 3ms/step - loss: 20.7859 - mae: 3.6256 - val_loss: 21.1560 - val_mae: 3.5667
# Epoch 35/60
# 239/239 [==============================] - 1s 4ms/step - loss: 20.5644 - mae: 3.6059 - val_loss: 21.3667 - val_mae: 3.5667
# Epoch 36/60
# 239/239 [==============================] - 1s 4ms/step - loss: 20.4359 - mae: 3.5921 - val_loss: 21.3928 - val_mae: 3.5642
# Epoch 37/60
# 239/239 [==============================] - 1s 4ms/step - loss: 20.4132 - mae: 3.5888 - val_loss: 21.2095 - val_mae: 3.5868
# Epoch 38/60
# 239/239 [==============================] - 1s 3ms/step - loss: 20.2585 - mae: 3.5694 - val_loss: 21.4687 - val_mae: 3.5502
# Epoch 39/60
# 239/239 [==============================] - 1s 4ms/step - loss: 20.2919 - mae: 3.5708 - val_loss: 20.8134 - val_mae: 3.5548
# Epoch 40/60
# 239/239 [==============================] - 1s 4ms/step - loss: 20.1453 - mae: 3.5612 - val_loss: 22.5568 - val_mae: 3.6254
# Epoch 41/60
# 239/239 [==============================] - 1s 6ms/step - loss: 20.1933 - mae: 3.5532 - val_loss: 21.9176 - val_mae: 3.6475
# Epoch 42/60
# 239/239 [==============================] - 1s 5ms/step - loss: 19.8918 - mae: 3.5385 - val_loss: 20.6223 - val_mae: 3.5175
# Epoch 43/60
# 239/239 [==============================] - 1s 4ms/step - loss: 20.0167 - mae: 3.5418 - val_loss: 21.0775 - val_mae: 3.5410
# Epoch 44/60
# 239/239 [==============================] - 1s 4ms/step - loss: 19.7786 - mae: 3.5189 - val_loss: 20.3857 - val_mae: 3.4868
# Epoch 45/60
# 239/239 [==============================] - 1s 4ms/step - loss: 19.5552 - mae: 3.4998 - val_loss: 20.6300 - val_mae: 3.4631
# Epoch 46/60
# 239/239 [==============================] - 1s 3ms/step - loss: 19.2897 - mae: 3.4650 - val_loss: 21.2418 - val_mae: 3.4952
# Epoch 47/60
# 239/239 [==============================] - 1s 4ms/step - loss: 19.6017 - mae: 3.4841 - val_loss: 20.1659 - val_mae: 3.4409
# Epoch 48/60
# 239/239 [==============================] - 1s 4ms/step - loss: 19.3403 - mae: 3.4628 - val_loss: 20.2424 - val_mae: 3.4667
# Epoch 49/60
# 239/239 [==============================] - 1s 3ms/step - loss: 19.2859 - mae: 3.4647 - val_loss: 20.2574 - val_mae: 3.4440
# Epoch 50/60
# 239/239 [==============================] - 1s 4ms/step - loss: 19.0560 - mae: 3.4376 - val_loss: 20.1859 - val_mae: 3.4482
# Epoch 51/60
# 239/239 [==============================] - 1s 4ms/step - loss: 19.2348 - mae: 3.4426 - val_loss: 19.8667 - val_mae: 3.4291
# Epoch 52/60
# 239/239 [==============================] - 1s 4ms/step - loss: 19.0438 - mae: 3.4333 - val_loss: 20.1270 - val_mae: 3.4325
# Epoch 53/60
# 239/239 [==============================] - 1s 4ms/step - loss: 19.0677 - mae: 3.4374 - val_loss: 20.0545 - val_mae: 3.4491
# Epoch 54/60
# 239/239 [==============================] - 1s 6ms/step - loss: 19.0771 - mae: 3.4363 - val_loss: 19.8654 - val_mae: 3.3919
# Epoch 55/60
# 239/239 [==============================] - 3s 11ms/step - loss: 18.9248 - mae: 3.4175 - val_loss: 20.3398 - val_mae: 3.4966
# Epoch 56/60
# 239/239 [==============================] - 1s 5ms/step - loss: 19.0809 - mae: 3.4266 - val_loss: 19.7450 - val_mae: 3.4133
# Epoch 57/60
# 239/239 [==============================] - 1s 3ms/step - loss: 18.9045 - mae: 3.4146 - val_loss: 19.8734 - val_mae: 3.3843
# Epoch 58/60
# 239/239 [==============================] - 1s 4ms/step - loss: 18.9844 - mae: 3.4280 - val_loss: 19.8263 - val_mae: 3.4335
# Epoch 59/60
# 239/239 [==============================] - 1s 4ms/step - loss: 19.2633 - mae: 3.4461 - val_loss: 20.3789 - val_mae: 3.4912
# Epoch 60/60
# 239/239 [==============================] - 1s 3ms/step - loss: 18.9949 - mae: 3.4163 - val_loss: 19.8732 - val_mae: 3.3967

# %%
hist.history["loss"]
# Out:
# [201974.203125,
#  159537.96875,
#  73884.2578125,
#  27797.96875,
#  18489.634765625,
#  13156.904296875,
#  8422.45703125,
#  4750.28271484375,
#  2422.247802734375,
#  1188.1083984375,
#  614.0962524414062,
#  353.7203063964844,
#  225.33551025390625,
#  154.25433349609375,
#  110.90601348876953,
#  83.46065521240234,
#  65.0351791381836,
#  53.10811996459961,
#  44.939178466796875,
#  39.19615173339844,
#  35.052371978759766,
#  31.870752334594727,
#  29.3142147064209,
#  27.400875091552734,
#  25.801483154296875,
#  24.505287170410156,
#  23.44107437133789,
#  22.717931747436523,
#  22.181623458862305,
#  21.64202308654785,
#  21.334726333618164,
#  21.049362182617188,
#  20.884437561035156,
#  20.785947799682617,
#  20.56441307067871,
#  20.435863494873047,
#  20.413204193115234,
#  20.25845718383789,
#  20.291879653930664,
#  20.145261764526367,
#  20.193307876586914,
#  19.89178466796875,
#  20.016674041748047,
#  19.778614044189453,
#  19.55517578125,
#  19.28969955444336,
#  19.601736068725586,
#  19.340267181396484,
#  19.285886764526367,
#  19.0560245513916,
#  19.234846115112305,
#  19.043766021728516,
#  19.06769561767578,
#  19.077075958251953,
#  18.92478370666504,
#  19.080873489379883,
#  18.904542922973633,
#  18.984403610229492,
#  19.263341903686523,
#  18.994876861572266]

# %%
hist.history['val_loss']
# Out:
# [191438.1875,
#  118414.8359375,
#  41237.21484375,
#  22353.080078125,
#  16180.5537109375,
#  10890.9443359375,
#  6475.81591796875,
#  3410.14453125,
#  1666.3011474609375,
#  821.83837890625,
#  443.605224609375,
#  271.2042541503906,
#  178.7834014892578,
#  127.0488052368164,
#  94.47512817382812,
#  72.46788024902344,
#  57.30419921875,
#  48.459815979003906,
#  41.46976089477539,
#  36.703704833984375,
#  33.065879821777344,
#  30.327518463134766,
#  29.149391174316406,
#  26.966102600097656,
#  25.30006980895996,
#  24.308303833007812,
#  23.652515411376953,
#  23.002779006958008,
#  22.55687713623047,
#  22.052831649780273,
#  22.192903518676758,
#  21.651031494140625,
#  21.494041442871094,
#  21.155996322631836,
#  21.3666934967041,
#  21.39280128479004,
#  21.209518432617188,
#  21.46868896484375,
#  20.81336784362793,
#  22.556753158569336,
#  21.917560577392578,
#  20.622312545776367,
#  21.07750129699707,
#  20.385740280151367,
#  20.62998390197754,
#  21.241811752319336,
#  20.16594123840332,
#  20.242443084716797,
#  20.257356643676758,
#  20.185897827148438,
#  19.86674690246582,
#  20.126985549926758,
#  20.05445098876953,
#  19.86536407470703,
#  20.33981704711914,
#  19.74497413635254,
#  19.873353958129883,
#  19.826276779174805,
#  20.37887954711914,
#  19.873239517211914]

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history["loss"], label="Training Loss")
plt.plot(hist.history["val_loss"], label="Validation Loss")
plt.xlabel("Number of Epochs")
plt.ylabel("Mean Squared Error")
plt.title("Learning Curve")
plt.legend()
plt.show()

# %%
model.evaluate(xtrain, ytrain)
# Out:
# 239/239 [==============================] - 0s 2ms/step - loss: 18.7367 - mae: 3.3880
# [18.736679077148438, 3.3879899978637695]

# %%
model.evaluate(xtest, ytest)
# Out:
# 60/60 [==============================] - 0s 4ms/step - loss: 19.8732 - mae: 3.3967
# [19.873239517211914, 3.396665573120117]

# %% [markdown]
# Predict the results for train and test

# %%
ypred_train = model.predict(xtrain)
ypred_test = model.predict(xtest)
# Out:
# 239/239 [==============================] - 1s 3ms/step
# 60/60 [==============================] - 0s 1ms/step

# %%
ypred_train[0:5]
# Out:
# array([[482.06992],
#        [467.79498],
#        [443.42804],
#        [442.26636],
#        [467.57092]], dtype=float32)

# %%
ytrain.head()
# Out:
#           PE
# 7081  485.83
# 2258  469.69
# 659   447.73
# 9441  448.76
# 8478  469.09

# %%
ypred_test[0:5]
# Out:
# array([[432.11893],
#        [433.99   ],
#        [439.27194],
#        [450.95145],
#        [454.71136]], dtype=float32)

# %%
ytest.head()
# Out:
#           PE
# 8316  427.65
# 9265  430.22
# 4287  445.80
# 5889  450.50
# 119   459.47

# %%
# R2 score in train
from sklearn.metrics import r2_score
r2_score(ytrain, ypred_train)
# Out:
# 0.9355469078901842

# %%
# R2 score in test
r2_score(ytest, ypred_test)
# Out:
# 0.931157246830031

# %% [markdown]
# Because I have r2 score > 0.8 for both train and test i can use above model for out of sample prediction

# %%
url2 = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/main/test_PowerPlant.csv"
xnew = pd.read_csv(url2)
xnew.head()
# Out:
#       AT      V       AP     RH
# 0  22.49  58.82  1009.73  85.19
# 1  28.88  54.89  1007.16  46.60
# 2  27.89  73.21  1001.32  85.88
# 3  25.69  62.26  1011.38  74.08
# 4  12.16  40.81  1025.79  70.97

# %%
num_pipe
# Out:
# Pipeline(steps=[('impute', SimpleImputer()), ('scale', StandardScaler())])

# %%
xnew_pre = num_pipe.transform(xnew)
xnew_pre.head()
# Out:
#          AT         V        AP        RH
# 0  0.380410  0.356827 -0.590397  0.811615
# 1  1.238819  0.047028 -1.023041 -1.830315
# 2  1.105826  1.491180 -2.006171  0.858853
# 3  0.810286  0.628000 -0.312629  0.051007
# 4 -1.007284 -1.062888  2.113209 -0.161908

# %%
preds = model.predict(xnew_pre)
preds[0:5]
# Out:
# 4/4 [==============================] - 0s 4ms/step
# array([[444.14957],
#        [437.75452],
#        [431.40543],
#        [438.8647 ],
#        [471.57532]], dtype=float32)

# %%
xnew["PowerOutput_pred"] = preds

# %%
xnew
# Out:
#        AT      V       AP     RH  PowerOutput_pred
# 0   22.49  58.82  1009.73  85.19        444.149567
# 1   28.88  54.89  1007.16  46.60        437.754517
# 2   27.89  73.21  1001.32  85.88        431.405426
# 3   25.69  62.26  1011.38  74.08        438.864685
# 4   12.16  40.81  1025.79  70.97        471.575317
# ..    ...    ...      ...    ...               ...
# 95  26.35  69.48  1008.45  70.47        435.138245
# 96  11.78  39.96  1011.37  82.95        472.048279
# 97   5.62  41.38  1020.91  86.21        483.471893
# 98  24.96  74.99  1008.25  80.52        434.674744
# 99   9.48  40.80  1023.82  78.98        476.311157
#
# [100 rows x 5 columns]

# %%
import seaborn as sns
sns.histplot(data=xnew, x="PowerOutput_pred", kde=True)
# Out:
# <Axes: xlabel='PowerOutput_pred', ylabel='Count'>

# %%
xnew.to_csv("Results.csv", index=False)
